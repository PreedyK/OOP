# %% [markdown]
# <a href="https://colab.research.google.com/github/PreedyK/OOP/blob/main/PreedyK_Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("data01.csv")

x = df["median_house_value"].median()
print("Median:", x)
# Out:
# Median: 175050.0

# %%
import pandas as pd
df = pd.read_csv("data01.csv")

for z in df.index:
  if df.loc[z, "total_rooms"] < 500:
    x = df["total_rooms"].median
    df.fillna({"total_rooms":x}, inplace=True)

# %%
import pandas as pd
df = pd.read_csv("data01.csv")

for x in df.index:
  if df.loc[x, "housing_median_age"] < 25:
    print(x)
# Out:
# 4
# 7
# 8
# 13
# 16
# 24
# 28
# 30
# 32
# 33
# 39
# 40
# 41
# 45
# 46
# 48
# 49
# 50
# 51
# 56
# 59
# 61
# 66
# 67
# 68
# 72
# 74
# 78
# 79
# 83
# 84
# 88
# 90
# 93
# 96
# 97
# 98
# 107
# 110
# 114
# 116
# 118
# 120
# 124
# 126
# 131
# 136
# 140
# 142
# 143
# 144
# 146
# 152
# 153
# 154
# 155
# 159
# 161
# 162
# 164
# 165
# 168
# 169
# 176
# 177
# 178
# 182
# 183
# 184
# 187
# 190
# 195
# 196
# 201
# 202
# 203
# 209
# 211
# 212
# 215
# 216
# 217
# 228
# 230
# 231
# 234
# 235
# 237
# 240
# 241
# 242
# 244
# 246
# 247
# 248
# 249
# 250
# 252
# 253
# 254
# 256
# 258
# 262
# 264
# 269
# 274
# 276
# 277
# 284
# 285
# 286
# 290
# 292
# 295
# 297
# 298
# 303
# 307
# 312
# 316
# 321
# 322
# 323
# 328
# 329
# 333
# 336
# 339
# 346
# 348
# 352
# 357
# 358
# 360
# 362
# 364
# 366
# 367
# 372
# 375
# 378
# 383
# 386
# 388
# 389
# 394
# 395
# 400
# 403
# 405
# 408
# 413
# 418
# 423
# 426
# 427
# 429
# 430
# 433
# 434
# 435
# 438
# 443
# 444
# 446
# 447
# 459
# 461
# 462
# 466
# 468
# 471
# 473
# ...

# %%
import pandas as pd
df = pd.read_csv("data01.csv")

import matplotlib.pyplot as plt

df.plot()
plt.show()

df.plot(kind = "bar", x = "median_income", y = "median_house_value")
plt.show()
df
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.05     37.37                  27         3885             661
# 1      -118.30     34.26                  43         1510             310
# 2      -117.81     33.78                  27         3589             507
# 3      -118.36     33.82                  28           67              15
# 4      -119.67     36.33                  19         1241             244
# ..         ...       ...                 ...          ...             ...
# 495    -122.29     37.82                   2          158              43
# 496    -116.31     33.65                   8         3079             558
# 497    -118.27     34.01                  43         1235             385
# 498    -122.44     37.76                  52         1968             472
# 499    -118.27     34.15                  14         1744             536
#
#      population  households  median_income  median_house_value
# ...
